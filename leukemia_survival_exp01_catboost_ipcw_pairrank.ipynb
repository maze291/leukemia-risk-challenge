# %% [markdown]
# # EXP01 CatBoost IPCW Pair-Rank Diagnostics
#
# This notebook runs the EXP01 CatBoost pair-ranking experiment through `leukemia_survival_exp01_catboost_ipcw_pairrank.py`. The default quick-check path verifies dependencies, feature shapes, pair construction, and submission guards before any full cross-validation run.

# %%
# Quick check only. This does not run full CatBoost CV and does not generate submissions.
import os
os.environ['EXP01_QUICK_CHECK_ONLY'] = '1'
os.environ['RUN_RANDOM_KFOLD_DIAGNOSTIC'] = '0'
os.environ['RUN_LOCO_DIAGNOSTIC'] = '0'
os.environ['SAVE_EXP01_SUBMISSIONS'] = '0'
# %run leukemia_survival_exp01_catboost_ipcw_pairrank.py

# %%
# Full diagnostic run, for later approval only. No submissions are generated.
# import os
# os.environ.pop('EXP01_QUICK_CHECK_ONLY', None)
# os.environ['RUN_RANDOM_KFOLD_DIAGNOSTIC'] = '0'
# os.environ['RUN_LOCO_DIAGNOSTIC'] = '0'
# os.environ['SAVE_EXP01_SUBMISSIONS'] = '0'
# %run leukemia_survival_exp01_catboost_ipcw_pairrank.py
